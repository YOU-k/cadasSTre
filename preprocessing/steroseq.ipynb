# %%
import pysam
from collections import Counter
import gzip
import os
import random

# %%
def get_tags_from_bam(bamfile_path, gene_tag, UMI_tag,sub_props):
    # List to store tags
    gene_count_dict = {sub_prop: {} for sub_prop in sub_props}
    res_cnt = {sub_prop: Counter() for sub_prop in sub_props}
    # Open the BAM file
    idx = 0
    with pysam.AlignmentFile(bamfile_path, "rb",require_index=False) as bamfile:
        # Iterate over each read
        for read in bamfile:
            idx += 1
            if read.has_tag("GE"):
                gene = read.get_tag(gene_tag, with_value_type=False)
            else: gene = None
            cx_value = int(read.get_tag("Cx"))
            cy_value = int(read.get_tag("Cy"))
            bc = f"{cx_value}_{cy_value}"

            UMI = read.get_tag(UMI_tag, with_value_type=False)
            for sub_prop in sub_props:
                random_num = random.randint(0, 99)
                if random_num < sub_prop * 100:
                    # Check if the tag is present in the read
                    if (gene is not None) and (bc is not None) and (UMI is not None):
                        # Add the tag value to the list
                        if gene not in gene_count_dict[sub_prop]:
                            gene_count_dict[sub_prop][gene] = {}
                        gene_count_dict[sub_prop][gene].setdefault(bc, set()).add(UMI)
                        res_cnt[sub_prop]["transcriptomic"] += 1 
                    
            if idx % 1000000 ==0:
                print(f"Total reads processed: {idx}")
                print(res_cnt[sub_prop])
        for sub_prop in sub_props:
            for gene in gene_count_dict[sub_prop]:
                gene_count_dict[sub_prop][gene] = {bc: len(gene_count_dict[sub_prop][gene][bc]) for bc in gene_count_dict[sub_prop][gene]}

    return gene_count_dict,res_cnt

# %%
def write_mtx(gene_count_dict, out_dir):
    """
    gene_count_dict: dict in dict {gene_id: {barcode: UMI_count}, ... }
    """
    gene_list = []  # Create an empty list to store gene IDs
    bc_list = []    # Create an empty list to store barcode IDs
    
    # Iterate through the gene_count_dict to collect gene and barcode IDs
    for ge in gene_count_dict:
        gene_list.append(ge)
        for bc in gene_count_dict[ge]:
            bc_list.append(bc)
    
    total_cnt = len(bc_list)  # Calculate the total number of unique barcodes
    
    # Remove duplicate barcodes by converting the list to a set and back to a list
    bc_list = list(set(bc_list))
    
    # Create a dictionary to map gene IDs to their index (1-based indexing)
    probe_dict = dict([(pid, ix + 1) for ix, pid in enumerate(gene_list)])  # 1-based indexing
    
    # Create a dictionary to map barcode IDs to their index (1-based indexing)
    bc_dict = dict([(bc, ix + 1) for ix, bc in enumerate(bc_list)])  # 1-based indexing
    
    # Open and write the gene features file
    out_feature = gzip.open(os.path.join(out_dir, "digital_expression_features.tsv.gz"), "wb")
    for ge in gene_list:
        out_feature.write(ge.encode('utf-8') + b'\n')  # Write gene IDs to the file
    out_feature.close()
    
    # Open and write the barcode file
    out_barcode = gzip.open(os.path.join(out_dir, "digital_expression_barcodes.tsv.gz"), "wb")
    for bc in bc_list:
        out_barcode.write(bytes(bc + '\n', "UTF-8"))  # Write barcode IDs to the file
    out_barcode.close()
    
    # Open and write the matrix file in MatrixMarket format
    out_mtx = gzip.open(os.path.join(out_dir, "digital_expression_matrix.mtx.gz"), "wb")
    out_mtx.write(b'%%MatrixMarket matrix coordinate integer general\n%\n')  # Write MatrixMarket headers
    out_mtx.write(bytes("{}\t{}\t{}\n".format(len(gene_list), len(bc_list), total_cnt), "UTF-8" ))  # Write matrix dimensions
    for ge in gene_list:  # Iterate over genes
        for bc in gene_count_dict[ge]:  # Iterate over barcodes for each gene
            out_mtx.write(bytes("{}\t{}\t{}\n".format(probe_dict[ge], bc_dict[bc], gene_count_dict[ge][bc]), "UTF-8"))  # Write matrix data
    out_mtx.close()

# %%
if __name__ == "__main__":
    gene_tag = "GE"
    UMI_tag = "UR"
    bamfile_path = "mouse_brain_B02223D2.bam"  # replace with your bam file path
    gene_count_dict,res_cnt = get_tags_from_bam(bamfile_path, gene_tag, UMI_tag, sub_props1)
# Out:
# [E::idx_find_and_load] Could not retrieve index file for 'mouse_brain_B02223D2.bam'
# Total reads processed: 1000000
# Counter({'transcriptomic': 65267})
# Total reads processed: 2000000
# Counter({'transcriptomic': 144459})
# Total reads processed: 3000000
# Counter({'transcriptomic': 234968})
# Total reads processed: 4000000
# Counter({'transcriptomic': 283175})
# Total reads processed: 5000000
# Counter({'transcriptomic': 333009})
# Total reads processed: 6000000
# Counter({'transcriptomic': 403457})
# Total reads processed: 7000000
# Counter({'transcriptomic': 493057})
# Total reads processed: 8000000
# Counter({'transcriptomic': 565598})
# Total reads processed: 9000000
# Counter({'transcriptomic': 650244})
# Total reads processed: 10000000
# Counter({'transcriptomic': 650244})
# Total reads processed: 11000000
# Counter({'transcriptomic': 650244})
# Total reads processed: 12000000
# Counter({'transcriptomic': 650244})
# Total reads processed: 13000000
# Counter({'transcriptomic': 650244})
# Total reads processed: 14000000
# Counter({'transcriptomic': 650244})
# Total reads processed: 15000000
# Counter({'transcriptomic': 650244})
# Total reads processed: 16000000
# Counter({'transcriptomic': 650244})
# Total reads processed: 17000000
# Counter({'transcriptomic': 650244})
# Total reads processed: 18000000
# Counter({'transcriptomic': 650244})
# Total reads processed: 19000000
# Counter({'transcriptomic': 650244})
# Total reads processed: 20000000
# Counter({'transcriptomic': 650244})
# Total reads processed: 21000000
# Counter({'transcriptomic': 650244})
# Total reads processed: 22000000
# Counter({'transcriptomic': 650244})
# Total reads processed: 23000000
# Counter({'transcriptomic': 650244})
# Total reads processed: 24000000
# Counter({'transcriptomic': 650244})
# Total reads processed: 25000000
# Counter({'transcriptomic': 650244})
# Total reads processed: 26000000
# Counter({'transcriptomic': 650244})
# Total reads processed: 27000000
# Counter({'transcriptomic': 650244})
# Total reads processed: 28000000
# Counter({'transcriptomic': 650244})
# Total reads processed: 29000000
# Counter({'transcriptomic': 650244})
# Total reads processed: 30000000
# Counter({'transcriptomic': 650244})
# Total reads processed: 31000000
# Counter({'transcriptomic': 650244})
# Total reads processed: 32000000
# Counter({'transcriptomic': 650245})
# Total reads processed: 33000000
# Counter({'transcriptomic': 650245})
# Total reads processed: 34000000
# Counter({'transcriptomic': 650245})
# Total reads processed: 35000000
# Counter({'transcriptomic': 650245})
# Total reads processed: 36000000
# Counter({'transcriptomic': 650245})
# Total reads processed: 37000000
# Counter({'transcriptomic': 650245})
# Total reads processed: 38000000
# Counter({'transcriptomic': 650245})
# Total reads processed: 39000000
# Counter({'transcriptomic': 650245})
# Total reads processed: 40000000
# Counter({'transcriptomic': 650245})
# Total reads processed: 41000000
# Counter({'transcriptomic': 650245})
# Total reads processed: 42000000
# Counter({'transcriptomic': 650245})
# Total reads processed: 43000000
# Counter({'transcriptomic': 675505})
# Total reads processed: 44000000
# Counter({'transcriptomic': 744639})
# Total reads processed: 45000000
# Counter({'transcriptomic': 827787})
# Total reads processed: 46000000
# Counter({'transcriptomic': 920866})
# Total reads processed: 47000000
# Counter({'transcriptomic': 995142})
# Total reads processed: 48000000
# Counter({'transcriptomic': 1070978})
# Total reads processed: 49000000
# Counter({'transcriptomic': 1170924})
# Total reads processed: 50000000
# Counter({'transcriptomic': 1267747})
# Total reads processed: 51000000
# Counter({'transcriptomic': 1336604})
# Total reads processed: 52000000
# Counter({'transcriptomic': 1427537})
# Total reads processed: 53000000
# Counter({'transcriptomic': 1507198})
# Total reads processed: 54000000
# Counter({'transcriptomic': 1588069})
# Total reads processed: 55000000
# Counter({'transcriptomic': 1674070})
# Total reads processed: 56000000
# Counter({'transcriptomic': 1763824})
# Total reads processed: 57000000
# Counter({'transcriptomic': 1799756})
# Total reads processed: 58000000
# Counter({'transcriptomic': 1812302})
# Total reads processed: 59000000
# Counter({'transcriptomic': 1897713})
# Total reads processed: 60000000
# Counter({'transcriptomic': 1980041})
# Total reads processed: 61000000
# Counter({'transcriptomic': 2061205})
# Total reads processed: 62000000
# Counter({'transcriptomic': 2144823})
# Total reads processed: 63000000
# Counter({'transcriptomic': 2217929})
# Total reads processed: 64000000
# Counter({'transcriptomic': 2312596})
# Total reads processed: 65000000
# Counter({'transcriptomic': 2386986})
# Total reads processed: 66000000
# Counter({'transcriptomic': 2468294})
# Total reads processed: 67000000
# Counter({'transcriptomic': 2526610})
# Total reads processed: 68000000
# Counter({'transcriptomic': 2624063})
# Total reads processed: 69000000
# Counter({'transcriptomic': 2682830})
# Total reads processed: 70000000
# Counter({'transcriptomic': 2774627})
# Total reads processed: 71000000
# Counter({'transcriptomic': 2857347})
# Total reads processed: 72000000
# Counter({'transcriptomic': 2932375})
# Total reads processed: 73000000
# Counter({'transcriptomic': 3019349})
# Total reads processed: 74000000
# Counter({'transcriptomic': 3095403})
# Total reads processed: 75000000
# Counter({'transcriptomic': 3181557})
# Total reads processed: 76000000
# Counter({'transcriptomic': 3267672})
# Total reads processed: 77000000
# Counter({'transcriptomic': 3357313})
# Total reads processed: 78000000
# Counter({'transcriptomic': 3457048})
# Total reads processed: 79000000
# Counter({'transcriptomic': 3547771})
# Total reads processed: 80000000
# Counter({'transcriptomic': 3638876})
# Total reads processed: 81000000
# Counter({'transcriptomic': 3728963})
# Total reads processed: 82000000
# Counter({'transcriptomic': 3819588})
# Total reads processed: 83000000
# Counter({'transcriptomic': 3893121})
# Total reads processed: 84000000
# Counter({'transcriptomic': 3979772})
# Total reads processed: 85000000
# Counter({'transcriptomic': 4068990})
# Total reads processed: 86000000
# Counter({'transcriptomic': 4134185})
# Total reads processed: 87000000
# Counter({'transcriptomic': 4233545})
# Total reads processed: 88000000
# Counter({'transcriptomic': 4332875})
# Total reads processed: 89000000
# Counter({'transcriptomic': 4432883})
# Total reads processed: 90000000
# Counter({'transcriptomic': 4526753})
# Total reads processed: 91000000
# Counter({'transcriptomic': 4621576})
# Total reads processed: 92000000
# Counter({'transcriptomic': 4653464})
# Total reads processed: 93000000
# Counter({'transcriptomic': 4714648})
# Total reads processed: 94000000
# Counter({'transcriptomic': 4800815})
# Total reads processed: 95000000
# Counter({'transcriptomic': 4881723})
# Total reads processed: 96000000
# Counter({'transcriptomic': 4975730})
# Total reads processed: 97000000
# Counter({'transcriptomic': 5069161})
# Total reads processed: 98000000
# Counter({'transcriptomic': 5168991})
# Total reads processed: 99000000
# Counter({'transcriptomic': 5266485})
# Total reads processed: 100000000
# Counter({'transcriptomic': 5355799})
# Total reads processed: 101000000
# Counter({'transcriptomic': 5445529})
# Total reads processed: 102000000
# Counter({'transcriptomic': 5507758})
# Total reads processed: 103000000
# Counter({'transcriptomic': 5534938})
# Total reads processed: 104000000
# Counter({'transcriptomic': 5534938})
# Total reads processed: 105000000
# Counter({'transcriptomic': 5534938})
# Total reads processed: 106000000
# Counter({'transcriptomic': 5534938})
# Total reads processed: 107000000
# Counter({'transcriptomic': 5550464})
# Total reads processed: 108000000
# Counter({'transcriptomic': 5621137})
# Total reads processed: 109000000
# Counter({'transcriptomic': 5702595})
# Total reads processed: 110000000
# Counter({'transcriptomic': 5801115})
# Total reads processed: 111000000
# Counter({'transcriptomic': 5853343})
# Total reads processed: 112000000
# Counter({'transcriptomic': 5853343})
# Total reads processed: 113000000
# Counter({'transcriptomic': 5872796})
# Total reads processed: 114000000
# Counter({'transcriptomic': 5925527})
# Total reads processed: 115000000
# Counter({'transcriptomic': 5996496})
# Total reads processed: 116000000
# Counter({'transcriptomic': 6069940})
# Total reads processed: 117000000
# Counter({'transcriptomic': 6148943})
# Total reads processed: 118000000
# Counter({'transcriptomic': 6234663})
# Total reads processed: 119000000
# Counter({'transcriptomic': 6315954})
# Total reads processed: 120000000
# Counter({'transcriptomic': 6397902})
# Total reads processed: 121000000
# Counter({'transcriptomic': 6491451})
# Total reads processed: 122000000
# Counter({'transcriptomic': 6574911})
# Total reads processed: 123000000
# Counter({'transcriptomic': 6656676})
# Total reads processed: 124000000
# Counter({'transcriptomic': 6739648})
# Total reads processed: 125000000
# Counter({'transcriptomic': 6826021})
# Total reads processed: 126000000
# Counter({'transcriptomic': 6906869})
# Total reads processed: 127000000
# Counter({'transcriptomic': 6985517})
# Total reads processed: 128000000
# Counter({'transcriptomic': 7070979})
# Total reads processed: 129000000
# Counter({'transcriptomic': 7156392})
# Total reads processed: 130000000
# Counter({'transcriptomic': 7231114})
# Total reads processed: 131000000
# Counter({'transcriptomic': 7325614})
# Total reads processed: 132000000
# Counter({'transcriptomic': 7414993})
# Total reads processed: 133000000
# Counter({'transcriptomic': 7469324})
# Total reads processed: 134000000
# Counter({'transcriptomic': 7512520})
# Total reads processed: 135000000
# Counter({'transcriptomic': 7585061})
# Total reads processed: 136000000
# Counter({'transcriptomic': 7679682})
# Total reads processed: 137000000
# Counter({'transcriptomic': 7705636})
# Total reads processed: 138000000
# Counter({'transcriptomic': 7796382})
# Total reads processed: 139000000
# Counter({'transcriptomic': 7879806})
# Total reads processed: 140000000
# Counter({'transcriptomic': 7974463})
# Total reads processed: 141000000
# Counter({'transcriptomic': 8074640})
# Total reads processed: 142000000
# Counter({'transcriptomic': 8173956})
# Total reads processed: 143000000
# Counter({'transcriptomic': 8270512})
# Total reads processed: 144000000
# Counter({'transcriptomic': 8362614})
# Total reads processed: 145000000
# Counter({'transcriptomic': 8455194})
# Total reads processed: 146000000
# Counter({'transcriptomic': 8539228})
# Total reads processed: 147000000
# Counter({'transcriptomic': 8628164})
# Total reads processed: 148000000
# Counter({'transcriptomic': 8716274})
# Total reads processed: 149000000
# Counter({'transcriptomic': 8778177})
# Total reads processed: 150000000
# Counter({'transcriptomic': 8851515})
# Total reads processed: 151000000
# Counter({'transcriptomic': 8947300})
# Total reads processed: 152000000
# Counter({'transcriptomic': 9039362})
# Total reads processed: 153000000
# Counter({'transcriptomic': 9117583})
# Total reads processed: 154000000
# Counter({'transcriptomic': 9202722})
# Total reads processed: 155000000
# Counter({'transcriptomic': 9298744})
# Total reads processed: 156000000
# Counter({'transcriptomic': 9398624})
# Total reads processed: 157000000
# Counter({'transcriptomic': 9496060})
# Total reads processed: 158000000
# Counter({'transcriptomic': 9586765})
# Total reads processed: 159000000
# Counter({'transcriptomic': 9674622})
# Total reads processed: 160000000
# Counter({'transcriptomic': 9759103})
# Total reads processed: 161000000
# Counter({'transcriptomic': 9843692})
# Total reads processed: 162000000
# Counter({'transcriptomic': 9918800})
# Total reads processed: 163000000
# Counter({'transcriptomic': 10009115})
# Total reads processed: 164000000
# Counter({'transcriptomic': 10091666})
# Total reads processed: 165000000
# Counter({'transcriptomic': 10155985})
# Total reads processed: 166000000
# Counter({'transcriptomic': 10242249})
# Total reads processed: 167000000
# Counter({'transcriptomic': 10333707})
# Total reads processed: 168000000
# Counter({'transcriptomic': 10421115})
# Total reads processed: 169000000
# Counter({'transcriptomic': 10499823})
# Total reads processed: 170000000
# Counter({'transcriptomic': 10590638})
# Total reads processed: 171000000
# Counter({'transcriptomic': 10635039})
# Total reads processed: 172000000
# Counter({'transcriptomic': 10692412})
# Total reads processed: 173000000
# Counter({'transcriptomic': 10743258})
# Total reads processed: 174000000
# Counter({'transcriptomic': 10820780})
# Total reads processed: 175000000
# Counter({'transcriptomic': 10848818})
# Total reads processed: 176000000
# Counter({'transcriptomic': 10940915})
# Total reads processed: 177000000
# Counter({'transcriptomic': 11004670})
# Total reads processed: 178000000
# Counter({'transcriptomic': 11071478})
# Total reads processed: 179000000
# Counter({'transcriptomic': 11157113})
# Total reads processed: 180000000
# Counter({'transcriptomic': 11170644})
# Total reads processed: 181000000
# Counter({'transcriptomic': 11170645})
# Total reads processed: 182000000
# Counter({'transcriptomic': 11236334})
# Total reads processed: 183000000
# Counter({'transcriptomic': 11321218})
# Total reads processed: 184000000
# Counter({'transcriptomic': 11409111})
# Total reads processed: 185000000
# Counter({'transcriptomic': 11502055})
# Total reads processed: 186000000
# Counter({'transcriptomic': 11562203})
# Total reads processed: 187000000
# Counter({'transcriptomic': 11634826})
# Total reads processed: 188000000
# Counter({'transcriptomic': 11713311})
# Total reads processed: 189000000
# Counter({'transcriptomic': 11800633})
# Total reads processed: 190000000
# Counter({'transcriptomic': 11878637})
# Total reads processed: 191000000
# Counter({'transcriptomic': 11951615})
# Total reads processed: 192000000
# Counter({'transcriptomic': 12028743})
# Total reads processed: 193000000
# Counter({'transcriptomic': 12110240})
# Total reads processed: 194000000
# Counter({'transcriptomic': 12184620})
# Total reads processed: 195000000
# Counter({'transcriptomic': 12201409})
# Total reads processed: 196000000
# Counter({'transcriptomic': 12251114})
# Total reads processed: 197000000
# Counter({'transcriptomic': 12332827})
# Total reads processed: 198000000
# Counter({'transcriptomic': 12432190})
# Total reads processed: 199000000
# Counter({'transcriptomic': 12528375})
# Total reads processed: 200000000
# Counter({'transcriptomic': 12590214})
# Total reads processed: 201000000
# Counter({'transcriptomic': 12666949})
# Total reads processed: 202000000
# Counter({'transcriptomic': 12738201})
# Total reads processed: 203000000
# Counter({'transcriptomic': 12818208})
# Total reads processed: 204000000
# Counter({'transcriptomic': 12910045})
# Total reads processed: 205000000
# Counter({'transcriptomic': 12999725})
# Total reads processed: 206000000
# Counter({'transcriptomic': 13085032})
# Total reads processed: 207000000
# Counter({'transcriptomic': 13166020})
# Total reads processed: 208000000
# Counter({'transcriptomic': 13243551})
# Total reads processed: 209000000
# Counter({'transcriptomic': 13323791})
# Total reads processed: 210000000
# Counter({'transcriptomic': 13414501})
# Total reads processed: 211000000
# Counter({'transcriptomic': 13503525})
# Total reads processed: 212000000
# Counter({'transcriptomic': 13597894})
# Total reads processed: 213000000
# Counter({'transcriptomic': 13687385})
# Total reads processed: 214000000
# Counter({'transcriptomic': 13769267})
# Total reads processed: 215000000
# Counter({'transcriptomic': 13865686})
# Total reads processed: 216000000
# Counter({'transcriptomic': 13962264})
# Total reads processed: 217000000
# Counter({'transcriptomic': 14062584})
# Total reads processed: 218000000
# Counter({'transcriptomic': 14162151})
# Total reads processed: 219000000
# Counter({'transcriptomic': 14260053})
# Total reads processed: 220000000
# Counter({'transcriptomic': 14350242})
# Total reads processed: 221000000
# Counter({'transcriptomic': 14441300})
# Total reads processed: 222000000
# Counter({'transcriptomic': 14518714})
# Total reads processed: 223000000
# Counter({'transcriptomic': 14571257})
# Total reads processed: 224000000
# Counter({'transcriptomic': 14665536})
# Total reads processed: 225000000
# Counter({'transcriptomic': 14734027})
# Total reads processed: 226000000
# Counter({'transcriptomic': 14830917})
# Total reads processed: 227000000
# Counter({'transcriptomic': 14930008})
# Total reads processed: 228000000
# Counter({'transcriptomic': 15019493})
# Total reads processed: 229000000
# Counter({'transcriptomic': 15100800})
# Total reads processed: 230000000
# Counter({'transcriptomic': 15194781})
# Total reads processed: 231000000
# Counter({'transcriptomic': 15289851})
# Total reads processed: 232000000
# Counter({'transcriptomic': 15382697})
# Total reads processed: 233000000
# Counter({'transcriptomic': 15476969})
# Total reads processed: 234000000
# Counter({'transcriptomic': 15573646})
# Total reads processed: 235000000
# Counter({'transcriptomic': 15660949})
# Total reads processed: 236000000
# Counter({'transcriptomic': 15759686})
# Total reads processed: 237000000
# Counter({'transcriptomic': 15849879})
# Total reads processed: 238000000
# Counter({'transcriptomic': 15935649})
# Total reads processed: 239000000
# Counter({'transcriptomic': 16031844})
# Total reads processed: 240000000
# Counter({'transcriptomic': 16126638})
# Total reads processed: 241000000
# Counter({'transcriptomic': 16217042})
# Total reads processed: 242000000
# Counter({'transcriptomic': 16312404})
# Total reads processed: 243000000
# Counter({'transcriptomic': 16405289})
# Total reads processed: 244000000
# Counter({'transcriptomic': 16497477})
# Total reads processed: 245000000
# Counter({'transcriptomic': 16581164})
# Total reads processed: 246000000
# Counter({'transcriptomic': 16653128})
# Total reads processed: 247000000
# Counter({'transcriptomic': 16739877})
# Total reads processed: 248000000
# Counter({'transcriptomic': 16829461})
# Total reads processed: 249000000
# Counter({'transcriptomic': 16922204})
# Total reads processed: 250000000
# Counter({'transcriptomic': 17021803})
# Total reads processed: 251000000
# Counter({'transcriptomic': 17109899})
# Total reads processed: 252000000
# Counter({'transcriptomic': 17182969})
# Total reads processed: 253000000
# Counter({'transcriptomic': 17262166})
# Total reads processed: 254000000
# Counter({'transcriptomic': 17362272})
# Total reads processed: 255000000
# Counter({'transcriptomic': 17444991})
# Total reads processed: 256000000
# Counter({'transcriptomic': 17529785})
# Total reads processed: 257000000
# Counter({'transcriptomic': 17622850})
# Total reads processed: 258000000
# Counter({'transcriptomic': 17705340})
# Total reads processed: 259000000
# Counter({'transcriptomic': 17788443})
# Total reads processed: 260000000
# Counter({'transcriptomic': 17872009})
# Total reads processed: 261000000
# Counter({'transcriptomic': 17915665})
# Total reads processed: 262000000
# Counter({'transcriptomic': 17948188})
# Total reads processed: 263000000
# Counter({'transcriptomic': 18030691})
# Total reads processed: 264000000
# Counter({'transcriptomic': 18122004})
# Total reads processed: 265000000
# Counter({'transcriptomic': 18193320})
# Total reads processed: 266000000
# Counter({'transcriptomic': 18270920})
# Total reads processed: 267000000
# Counter({'transcriptomic': 18362087})
# Total reads processed: 268000000
# Counter({'transcriptomic': 18440026})
# Total reads processed: 269000000
# Counter({'transcriptomic': 18524711})
# Total reads processed: 270000000
# Counter({'transcriptomic': 18609143})
# Total reads processed: 271000000
# Counter({'transcriptomic': 18692088})
# Total reads processed: 272000000
# Counter({'transcriptomic': 18762120})
# Total reads processed: 273000000
# Counter({'transcriptomic': 18847354})
# Total reads processed: 274000000
# Counter({'transcriptomic': 18939906})
# Total reads processed: 275000000
# Counter({'transcriptomic': 19039481})
# Total reads processed: 276000000
# Counter({'transcriptomic': 19131332})
# Total reads processed: 277000000
# Counter({'transcriptomic': 19228354})
# Total reads processed: 278000000
# Counter({'transcriptomic': 19321881})
# Total reads processed: 279000000
# Counter({'transcriptomic': 19396663})
# Total reads processed: 280000000
# Counter({'transcriptomic': 19471557})
# Total reads processed: 281000000
# Counter({'transcriptomic': 19565925})
# Total reads processed: 282000000
# Counter({'transcriptomic': 19664495})
# Total reads processed: 283000000
# Counter({'transcriptomic': 19752768})
# Total reads processed: 284000000
# Counter({'transcriptomic': 19845393})
# Total reads processed: 285000000
# Counter({'transcriptomic': 19896266})
# Total reads processed: 286000000
# Counter({'transcriptomic': 19979932})
# Total reads processed: 287000000
# Counter({'transcriptomic': 20078073})
# Total reads processed: 288000000
# Counter({'transcriptomic': 20176347})
# Total reads processed: 289000000
# Counter({'transcriptomic': 20265767})
# Total reads processed: 290000000
# Counter({'transcriptomic': 20361801})
# Total reads processed: 291000000
# Counter({'transcriptomic': 20445345})
# Total reads processed: 292000000
# Counter({'transcriptomic': 20536293})
# Total reads processed: 293000000
# Counter({'transcriptomic': 20612129})
# Total reads processed: 294000000
# Counter({'transcriptomic': 20701075})
# Total reads processed: 295000000
# Counter({'transcriptomic': 20789718})
# Total reads processed: 296000000
# Counter({'transcriptomic': 20889934})
# Total reads processed: 297000000
# Counter({'transcriptomic': 20980883})
# Total reads processed: 298000000
# Counter({'transcriptomic': 21069723})
# Total reads processed: 299000000
# Counter({'transcriptomic': 21155398})
# Total reads processed: 300000000
# Counter({'transcriptomic': 21218411})
# Total reads processed: 301000000
# Counter({'transcriptomic': 21302048})
# Total reads processed: 302000000
# Counter({'transcriptomic': 21385582})
# Total reads processed: 303000000
# Counter({'transcriptomic': 21479083})
# Total reads processed: 304000000
# Counter({'transcriptomic': 21569886})
# Total reads processed: 305000000
# Counter({'transcriptomic': 21647534})
# Total reads processed: 306000000
# Counter({'transcriptomic': 21676079})
# Total reads processed: 307000000
# Counter({'transcriptomic': 21759680})
# Total reads processed: 308000000
# Counter({'transcriptomic': 21832822})
# Total reads processed: 309000000
# Counter({'transcriptomic': 21913740})
# Total reads processed: 310000000
# Counter({'transcriptomic': 22005112})
# Total reads processed: 311000000
# Counter({'transcriptomic': 22100739})
# Total reads processed: 312000000
# Counter({'transcriptomic': 22186929})
# Total reads processed: 313000000
# Counter({'transcriptomic': 22266283})
# Total reads processed: 314000000
# Counter({'transcriptomic': 22351028})
# Total reads processed: 315000000
# Counter({'transcriptomic': 22396269})
# Total reads processed: 316000000
# Counter({'transcriptomic': 22484641})
# Total reads processed: 317000000
# Counter({'transcriptomic': 22578773})
# Total reads processed: 318000000
# Counter({'transcriptomic': 22676031})
# Total reads processed: 319000000
# Counter({'transcriptomic': 22762648})
# Total reads processed: 320000000
# Counter({'transcriptomic': 22847364})
# Total reads processed: 321000000
# Counter({'transcriptomic': 22944530})
# Total reads processed: 322000000
# Counter({'transcriptomic': 22992430})
# Total reads processed: 323000000
# Counter({'transcriptomic': 23052065})
# Total reads processed: 324000000
# Counter({'transcriptomic': 23078922})
# Total reads processed: 325000000
# Counter({'transcriptomic': 23078939})
# Total reads processed: 326000000
# Counter({'transcriptomic': 23089728})
# Total reads processed: 327000000
# Counter({'transcriptomic': 23158896})
# Total reads processed: 328000000
# Counter({'transcriptomic': 23233625})
# Total reads processed: 329000000
# Counter({'transcriptomic': 23327777})
# Total reads processed: 330000000
# Counter({'transcriptomic': 23396909})
# Total reads processed: 331000000
# Counter({'transcriptomic': 23473658})
# Total reads processed: 332000000
# Counter({'transcriptomic': 23550537})
# Total reads processed: 333000000
# Counter({'transcriptomic': 23627915})
# Total reads processed: 334000000
# Counter({'transcriptomic': 23709491})
# Total reads processed: 335000000
# Counter({'transcriptomic': 23803317})
# Total reads processed: 336000000
# Counter({'transcriptomic': 23895762})
# Total reads processed: 337000000
# Counter({'transcriptomic': 23988743})
# Total reads processed: 338000000
# Counter({'transcriptomic': 24081926})
# Total reads processed: 339000000
# Counter({'transcriptomic': 24180049})
# Total reads processed: 340000000
# Counter({'transcriptomic': 24276730})
# Total reads processed: 341000000
# Counter({'transcriptomic': 24370850})
# Total reads processed: 342000000
# Counter({'transcriptomic': 24452035})
# Total reads processed: 343000000
# Counter({'transcriptomic': 24547697})
# Total reads processed: 344000000
# Counter({'transcriptomic': 24645335})
# Total reads processed: 345000000
# Counter({'transcriptomic': 24726871})
# Total reads processed: 346000000
# Counter({'transcriptomic': 24812485})
# Total reads processed: 347000000
# Counter({'transcriptomic': 24907595})
# Total reads processed: 348000000
# Counter({'transcriptomic': 25007363})
# Total reads processed: 349000000
# Counter({'transcriptomic': 25092745})
# Total reads processed: 350000000
# Counter({'transcriptomic': 25189643})
# Total reads processed: 351000000
# Counter({'transcriptomic': 25275703})
# Total reads processed: 352000000
# Counter({'transcriptomic': 25352716})
# Total reads processed: 353000000
# Counter({'transcriptomic': 25411322})
# Total reads processed: 354000000
# Counter({'transcriptomic': 25503887})
# Total reads processed: 355000000
# Counter({'transcriptomic': 25584272})
# Total reads processed: 356000000
# Counter({'transcriptomic': 25675049})
# Total reads processed: 357000000
# Counter({'transcriptomic': 25761371})
# Total reads processed: 358000000
# Counter({'transcriptomic': 25855657})
# Total reads processed: 359000000
# Counter({'transcriptomic': 25940917})
# Total reads processed: 360000000
# Counter({'transcriptomic': 26025849})
# Total reads processed: 361000000
# Counter({'transcriptomic': 26111356})
# Total reads processed: 362000000
# Counter({'transcriptomic': 26194746})
# Total reads processed: 363000000
# Counter({'transcriptomic': 26259557})
# Total reads processed: 364000000
# Counter({'transcriptomic': 26259559})
# Total reads processed: 365000000
# Counter({'transcriptomic': 26259564})
# Total reads processed: 366000000
# Counter({'transcriptomic': 26259571})
# Total reads processed: 367000000
# Counter({'transcriptomic': 26259576})
# Total reads processed: 368000000
# Counter({'transcriptomic': 26259593})
# Total reads processed: 369000000
# Counter({'transcriptomic': 26354871})
# Total reads processed: 370000000
# Counter({'transcriptomic': 26453168})
# Total reads processed: 371000000
# Counter({'transcriptomic': 26521329})
# Total reads processed: 372000000
# Counter({'transcriptomic': 26587098})
# Total reads processed: 373000000
# Counter({'transcriptomic': 26678895})
# Total reads processed: 374000000
# Counter({'transcriptomic': 26773231})
# Total reads processed: 375000000
# Counter({'transcriptomic': 26841175})
# Total reads processed: 376000000
# Counter({'transcriptomic': 26933491})
# Total reads processed: 377000000
# Counter({'transcriptomic': 27023377})
# Total reads processed: 378000000
# Counter({'transcriptomic': 27113301})
# Total reads processed: 379000000
# Counter({'transcriptomic': 27193834})
# Total reads processed: 380000000
# Counter({'transcriptomic': 27272932})
# Total reads processed: 381000000
# Counter({'transcriptomic': 27367860})
# Total reads processed: 382000000
# Counter({'transcriptomic': 27462442})
# Total reads processed: 383000000
# Counter({'transcriptomic': 27553877})
# Total reads processed: 384000000
# Counter({'transcriptomic': 27652573})
# Total reads processed: 385000000
# Counter({'transcriptomic': 27745423})
# Total reads processed: 386000000
# Counter({'transcriptomic': 27839167})
# Total reads processed: 387000000
# Counter({'transcriptomic': 27931848})
# Total reads processed: 388000000
# Counter({'transcriptomic': 28026852})
# Total reads processed: 389000000
# Counter({'transcriptomic': 28126047})
# Total reads processed: 390000000
# Counter({'transcriptomic': 28220836})
# Total reads processed: 391000000
# Counter({'transcriptomic': 28308423})
# Total reads processed: 392000000
# Counter({'transcriptomic': 28401982})
# Total reads processed: 393000000
# Counter({'transcriptomic': 28496224})
# Total reads processed: 394000000
# Counter({'transcriptomic': 28572888})
# Total reads processed: 395000000
# Counter({'transcriptomic': 28648545})
# Total reads processed: 396000000
# Counter({'transcriptomic': 28705096})
# Total reads processed: 397000000
# Counter({'transcriptomic': 28782249})
# Total reads processed: 398000000
# Counter({'transcriptomic': 28862907})
# Total reads processed: 399000000
# Counter({'transcriptomic': 28953248})
# Total reads processed: 400000000
# Counter({'transcriptomic': 29015818})
# Total reads processed: 401000000
# Counter({'transcriptomic': 29080367})
# Total reads processed: 402000000
# Counter({'transcriptomic': 29169945})
# Total reads processed: 403000000
# Counter({'transcriptomic': 29259101})
# Total reads processed: 404000000
# Counter({'transcriptomic': 29345080})
# Total reads processed: 405000000
# Counter({'transcriptomic': 29436738})
# Total reads processed: 406000000
# Counter({'transcriptomic': 29536397})
# Total reads processed: 407000000
# Counter({'transcriptomic': 29625272})
# Total reads processed: 408000000
# Counter({'transcriptomic': 29711711})
# Total reads processed: 409000000
# Counter({'transcriptomic': 29796408})
# Total reads processed: 410000000
# Counter({'transcriptomic': 29875074})
# Total reads processed: 411000000
# Counter({'transcriptomic': 29965245})
# Total reads processed: 412000000
# Counter({'transcriptomic': 30039318})
# Total reads processed: 413000000
# Counter({'transcriptomic': 30126171})
# Total reads processed: 414000000
# Counter({'transcriptomic': 30215214})
# Total reads processed: 415000000
# Counter({'transcriptomic': 30294652})
# Total reads processed: 416000000
# Counter({'transcriptomic': 30365823})
# Total reads processed: 417000000
# Counter({'transcriptomic': 30447424})
# Total reads processed: 418000000
# Counter({'transcriptomic': 30531213})
# Total reads processed: 419000000
# Counter({'transcriptomic': 30608418})
# Total reads processed: 420000000
# Counter({'transcriptomic': 30703895})
# Total reads processed: 421000000
# Counter({'transcriptomic': 30802771})
# Total reads processed: 422000000
# Counter({'transcriptomic': 30891683})
# Total reads processed: 423000000
# Counter({'transcriptomic': 30956262})
# Total reads processed: 424000000
# Counter({'transcriptomic': 31041573})
# Total reads processed: 425000000
# Counter({'transcriptomic': 31127392})
# Total reads processed: 426000000
# Counter({'transcriptomic': 31227029})
# Total reads processed: 427000000
# Counter({'transcriptomic': 31318608})
# Total reads processed: 428000000
# Counter({'transcriptomic': 31410302})
# Total reads processed: 429000000
# Counter({'transcriptomic': 31498824})
# Total reads processed: 430000000
# Counter({'transcriptomic': 31587551})
# Total reads processed: 431000000
# Counter({'transcriptomic': 31666772})
# Total reads processed: 432000000
# Counter({'transcriptomic': 31751802})
# Total reads processed: 433000000
# Counter({'transcriptomic': 31836093})
# Total reads processed: 434000000
# Counter({'transcriptomic': 31921060})
# Total reads processed: 435000000
# Counter({'transcriptomic': 32015203})
# Total reads processed: 436000000
# Counter({'transcriptomic': 32065517})
# Total reads processed: 437000000
# Counter({'transcriptomic': 32152027})
# Total reads processed: 438000000
# Counter({'transcriptomic': 32220993})
# Total reads processed: 439000000
# Counter({'transcriptomic': 32298397})
# Total reads processed: 440000000
# Counter({'transcriptomic': 32396601})
# Total reads processed: 441000000
# Counter({'transcriptomic': 32493575})
# Total reads processed: 442000000
# Counter({'transcriptomic': 32590656})
# Total reads processed: 443000000
# Counter({'transcriptomic': 32672522})
# Total reads processed: 444000000
# Counter({'transcriptomic': 32765860})
# Total reads processed: 445000000
# Counter({'transcriptomic': 32859174})
# Total reads processed: 446000000
# Counter({'transcriptomic': 32922701})
# Total reads processed: 447000000
# Counter({'transcriptomic': 33000209})
# Total reads processed: 448000000
# Counter({'transcriptomic': 33096225})
# Total reads processed: 449000000
# Counter({'transcriptomic': 33183671})
# Total reads processed: 450000000
# Counter({'transcriptomic': 33277512})
# Total reads processed: 451000000
# Counter({'transcriptomic': 33360334})
# Total reads processed: 452000000
# Counter({'transcriptomic': 33432254})
# Total reads processed: 453000000
# Counter({'transcriptomic': 33515922})
# Total reads processed: 454000000
# Counter({'transcriptomic': 33594201})
# Total reads processed: 455000000
# Counter({'transcriptomic': 33688110})
# Total reads processed: 456000000
# Counter({'transcriptomic': 33776824})
# Total reads processed: 457000000
# Counter({'transcriptomic': 33870660})
# Total reads processed: 458000000
# Counter({'transcriptomic': 33961241})
# Total reads processed: 459000000
# Counter({'transcriptomic': 34039214})
# Total reads processed: 460000000
# Counter({'transcriptomic': 34118161})
# Total reads processed: 461000000
# Counter({'transcriptomic': 34204918})
# Total reads processed: 462000000
# Counter({'transcriptomic': 34302526})
# Total reads processed: 463000000
# Counter({'transcriptomic': 34381856})
# Total reads processed: 464000000
# Counter({'transcriptomic': 34473256})
# Total reads processed: 465000000
# Counter({'transcriptomic': 34553603})
# Total reads processed: 466000000
# Counter({'transcriptomic': 34590085})
# Total reads processed: 467000000
# Counter({'transcriptomic': 34590086})
# Total reads processed: 468000000
# Counter({'transcriptomic': 34590086})
# Total reads processed: 469000000
# Counter({'transcriptomic': 34590086})
# Total reads processed: 470000000
# Counter({'transcriptomic': 34590086})
# Total reads processed: 471000000
# Counter({'transcriptomic': 34590086})
# Total reads processed: 472000000
# Counter({'transcriptomic': 34590086})
# Total reads processed: 473000000
# Counter({'transcriptomic': 34590086})
# Total reads processed: 474000000
# Counter({'transcriptomic': 34590086})
# Total reads processed: 475000000
# Counter({'transcriptomic': 34590086})
# Total reads processed: 476000000
# Counter({'transcriptomic': 34590086})
# Total reads processed: 477000000
# Counter({'transcriptomic': 34590086})
# Total reads processed: 478000000
# Counter({'transcriptomic': 34590086})
# Total reads processed: 479000000
# Counter({'transcriptomic': 34590086})
# Total reads processed: 480000000
# Counter({'transcriptomic': 34590086})
# Total reads processed: 481000000
# Counter({'transcriptomic': 34590086})
# Total reads processed: 482000000
# Counter({'transcriptomic': 34590086})
# Total reads processed: 483000000
# Counter({'transcriptomic': 34590086})
# Total reads processed: 484000000
# Counter({'transcriptomic': 34590086})
# Total reads processed: 485000000
# Counter({'transcriptomic': 34590086})
# Total reads processed: 486000000
# Counter({'transcriptomic': 34590086})
# Total reads processed: 487000000
# Counter({'transcriptomic': 34590086})
# Total reads processed: 488000000
# Counter({'transcriptomic': 34590086})
# Total reads processed: 489000000
# Counter({'transcriptomic': 34590086})
# Total reads processed: 490000000
# Counter({'transcriptomic': 34590086})
# Total reads processed: 491000000
# Counter({'transcriptomic': 34590086})
# Total reads processed: 492000000
# Counter({'transcriptomic': 34590086})
# Total reads processed: 493000000
# Counter({'transcriptomic': 34590086})
# Total reads processed: 494000000
# Counter({'transcriptomic': 34590086})
# Total reads processed: 495000000
# Counter({'transcriptomic': 34590086})
# Total reads processed: 496000000
# Counter({'transcriptomic': 34590086})
# Total reads processed: 497000000
# Counter({'transcriptomic': 34597077})
# Total reads processed: 498000000
# Counter({'transcriptomic': 34687327})
# Total reads processed: 499000000
# Counter({'transcriptomic': 34767816})
# Total reads processed: 500000000
# Counter({'transcriptomic': 34815409})
# Total reads processed: 501000000
# Counter({'transcriptomic': 34891847})
# Total reads processed: 502000000
# Counter({'transcriptomic': 34977003})
# Total reads processed: 503000000
# Counter({'transcriptomic': 35068059})
# Total reads processed: 504000000
# Counter({'transcriptomic': 35167141})
# Total reads processed: 505000000
# Counter({'transcriptomic': 35250018})
# Total reads processed: 506000000
# Counter({'transcriptomic': 35340756})
# Total reads processed: 507000000
# Counter({'transcriptomic': 35400994})
# Total reads processed: 508000000
# Counter({'transcriptomic': 35490469})
# Total reads processed: 509000000
# Counter({'transcriptomic': 35576043})
# Total reads processed: 510000000
# Counter({'transcriptomic': 35662927})
# Total reads processed: 511000000
# Counter({'transcriptomic': 35747543})
# Total reads processed: 512000000
# Counter({'transcriptomic': 35836920})
# Total reads processed: 513000000
# Counter({'transcriptomic': 35921787})
# Total reads processed: 514000000
# Counter({'transcriptomic': 36020115})
# Total reads processed: 515000000
# Counter({'transcriptomic': 36110262})
# Total reads processed: 516000000
# Counter({'transcriptomic': 36182167})
# Total reads processed: 517000000
# Counter({'transcriptomic': 36271573})
# Total reads processed: 518000000
# Counter({'transcriptomic': 36363190})
# Total reads processed: 519000000
# Counter({'transcriptomic': 36456234})
# Total reads processed: 520000000
# Counter({'transcriptomic': 36533083})
# Total reads processed: 521000000
# Counter({'transcriptomic': 36619533})
# Total reads processed: 522000000
# Counter({'transcriptomic': 36701990})
# Total reads processed: 523000000
# Counter({'transcriptomic': 36786708})
# Total reads processed: 524000000
# Counter({'transcriptomic': 36852706})
# Total reads processed: 525000000
# Counter({'transcriptomic': 36929432})
# Total reads processed: 526000000
# Counter({'transcriptomic': 37018373})
# Total reads processed: 527000000
# Counter({'transcriptomic': 37018373})
# Total reads processed: 528000000
# Counter({'transcriptomic': 37101891})
# Total reads processed: 529000000
# Counter({'transcriptomic': 37184613})
# Total reads processed: 530000000
# Counter({'transcriptomic': 37263987})
# Total reads processed: 531000000
# Counter({'transcriptomic': 37353343})
# Total reads processed: 532000000
# Counter({'transcriptomic': 37433361})
# Total reads processed: 533000000
# Counter({'transcriptomic': 37498629})
# Total reads processed: 534000000
# Counter({'transcriptomic': 37589024})
# Total reads processed: 535000000
# Counter({'transcriptomic': 37651187})
# Total reads processed: 536000000
# Counter({'transcriptomic': 37736648})
# Total reads processed: 537000000
# Counter({'transcriptomic': 37821046})
# Total reads processed: 538000000
# Counter({'transcriptomic': 37901209})
# Total reads processed: 539000000
# Counter({'transcriptomic': 37962362})
# Total reads processed: 540000000
# Counter({'transcriptomic': 37962362})
# Total reads processed: 541000000
# Counter({'transcriptomic': 38011009})
# Total reads processed: 542000000
# Counter({'transcriptomic': 38096451})
# Total reads processed: 543000000
# Counter({'transcriptomic': 38162125})
# Total reads processed: 544000000
# Counter({'transcriptomic': 38233509})
# Total reads processed: 545000000
# Counter({'transcriptomic': 38321527})
# Total reads processed: 546000000
# Counter({'transcriptomic': 38404742})
# Total reads processed: 547000000
# Counter({'transcriptomic': 38428447})
# Total reads processed: 548000000
# Counter({'transcriptomic': 38514293})
# Total reads processed: 549000000
# Counter({'transcriptomic': 38593868})
# Total reads processed: 550000000
# Counter({'transcriptomic': 38682737})
# Total reads processed: 551000000
# Counter({'transcriptomic': 38728309})
# Total reads processed: 552000000
# Counter({'transcriptomic': 38802152})
# Total reads processed: 553000000
# Counter({'transcriptomic': 38868981})
# Total reads processed: 554000000
# Counter({'transcriptomic': 38934816})
# Total reads processed: 555000000
# Counter({'transcriptomic': 39020915})
# Total reads processed: 556000000
# Counter({'transcriptomic': 39075263})
# Total reads processed: 557000000
# Counter({'transcriptomic': 39161484})
# Total reads processed: 558000000
# Counter({'transcriptomic': 39261324})
# Total reads processed: 559000000
# Counter({'transcriptomic': 39358054})
# Total reads processed: 560000000
# Counter({'transcriptomic': 39451519})
# Total reads processed: 561000000
# Counter({'transcriptomic': 39539605})
# Total reads processed: 562000000
# Counter({'transcriptomic': 39580923})
# Total reads processed: 563000000
# Counter({'transcriptomic': 39654398})
# Total reads processed: 564000000
# Counter({'transcriptomic': 39727806})
# Total reads processed: 565000000
# Counter({'transcriptomic': 39775479})
# Total reads processed: 566000000
# Counter({'transcriptomic': 39872283})
# Total reads processed: 567000000
# Counter({'transcriptomic': 39971501})
# Total reads processed: 568000000
# Counter({'transcriptomic': 40066409})
# Total reads processed: 569000000
# Counter({'transcriptomic': 40107734})
# Total reads processed: 570000000
# Counter({'transcriptomic': 40155598})
# Total reads processed: 571000000
# Counter({'transcriptomic': 40251479})
# Total reads processed: 572000000
# Counter({'transcriptomic': 40344372})
# Total reads processed: 573000000
# Counter({'transcriptomic': 40419047})
# Total reads processed: 574000000
# Counter({'transcriptomic': 40505174})
# Total reads processed: 575000000
# Counter({'transcriptomic': 40576540})
# Total reads processed: 576000000
# Counter({'transcriptomic': 40646172})
# Total reads processed: 577000000
# Counter({'transcriptomic': 40736414})
# Total reads processed: 578000000
# Counter({'transcriptomic': 40826604})
# Total reads processed: 579000000
# Counter({'transcriptomic': 40908921})
# Total reads processed: 580000000
# Counter({'transcriptomic': 40978448})
# Total reads processed: 581000000
# Counter({'transcriptomic': 41073992})
# Total reads processed: 582000000
# Counter({'transcriptomic': 41141034})
# Total reads processed: 583000000
# Counter({'transcriptomic': 41217367})
# Total reads processed: 584000000
# Counter({'transcriptomic': 41275865})
# Total reads processed: 585000000
# Counter({'transcriptomic': 41343235})
# Total reads processed: 586000000
# Counter({'transcriptomic': 41419620})
# Total reads processed: 587000000
# Counter({'transcriptomic': 41514314})
# Total reads processed: 588000000
# Counter({'transcriptomic': 41611536})
# Total reads processed: 589000000
# Counter({'transcriptomic': 41709587})
# Total reads processed: 590000000
# Counter({'transcriptomic': 41806166})
# Total reads processed: 591000000
# Counter({'transcriptomic': 41904369})
# Total reads processed: 592000000
# Counter({'transcriptomic': 42004338})
# Total reads processed: 593000000
# Counter({'transcriptomic': 42104240})
# Total reads processed: 594000000
# Counter({'transcriptomic': 42203589})
# Total reads processed: 595000000
# Counter({'transcriptomic': 42303530})
# Total reads processed: 596000000
# Counter({'transcriptomic': 42389682})
# Total reads processed: 597000000
# Counter({'transcriptomic': 42489188})
# Total reads processed: 598000000
# Counter({'transcriptomic': 42547903})
# Total reads processed: 599000000
# Counter({'transcriptomic': 42561309})
# Total reads processed: 600000000
# Counter({'transcriptomic': 42651418})
# Total reads processed: 601000000
# Counter({'transcriptomic': 42736704})
# Total reads processed: 602000000
# Counter({'transcriptomic': 42829669})
# Total reads processed: 603000000
# Counter({'transcriptomic': 42909862})
# Total reads processed: 604000000
# Counter({'transcriptomic': 42996163})
# Total reads processed: 605000000
# Counter({'transcriptomic': 43079491})
# Total reads processed: 606000000
# Counter({'transcriptomic': 43158491})
# Total reads processed: 607000000
# Counter({'transcriptomic': 43236284})
# Total reads processed: 608000000
# Counter({'transcriptomic': 43243510})
# Total reads processed: 609000000
# Counter({'transcriptomic': 43320756})
# Total reads processed: 610000000
# Counter({'transcriptomic': 43362645})
# Total reads processed: 611000000
# Counter({'transcriptomic': 43434775})
# Total reads processed: 612000000
# Counter({'transcriptomic': 43466883})
# Total reads processed: 613000000
# Counter({'transcriptomic': 43530132})
# Total reads processed: 614000000
# Counter({'transcriptomic': 43620983})
# Total reads processed: 615000000
# Counter({'transcriptomic': 43719863})
# Total reads processed: 616000000
# Counter({'transcriptomic': 43819165})
# Total reads processed: 617000000
# Counter({'transcriptomic': 43911473})
# Total reads processed: 618000000
# Counter({'transcriptomic': 44005842})
# Total reads processed: 619000000
# Counter({'transcriptomic': 44105475})
# Total reads processed: 620000000
# Counter({'transcriptomic': 44202632})
# Total reads processed: 621000000
# Counter({'transcriptomic': 44299970})
# Total reads processed: 622000000
# Counter({'transcriptomic': 44389414})
# Total reads processed: 623000000
# Counter({'transcriptomic': 44479786})
# Total reads processed: 624000000
# Counter({'transcriptomic': 44528788})
# Total reads processed: 625000000
# Counter({'transcriptomic': 44606260})
# Total reads processed: 626000000
# Counter({'transcriptomic': 44692113})
# Total reads processed: 627000000
# Counter({'transcriptomic': 44749135})
# Total reads processed: 628000000
# Counter({'transcriptomic': 44749135})
# Total reads processed: 629000000
# Counter({'transcriptomic': 44820365})
# Total reads processed: 630000000
# Counter({'transcriptomic': 44864073})
# Total reads processed: 631000000
# Counter({'transcriptomic': 44952589})
# Total reads processed: 632000000
# Counter({'transcriptomic': 45029854})
# Total reads processed: 633000000
# Counter({'transcriptomic': 45109658})
# Total reads processed: 634000000
# Counter({'transcriptomic': 45200982})
# Total reads processed: 635000000
# Counter({'transcriptomic': 45222165})
# Total reads processed: 636000000
# Counter({'transcriptomic': 45251331})
# Total reads processed: 637000000
# Counter({'transcriptomic': 45340051})
# Total reads processed: 638000000
# Counter({'transcriptomic': 45432321})
# Total reads processed: 639000000
# Counter({'transcriptomic': 45473438})
# Total reads processed: 640000000
# Counter({'transcriptomic': 45560842})
# Total reads processed: 641000000
# Counter({'transcriptomic': 45659466})
# Total reads processed: 642000000
# Counter({'transcriptomic': 45759764})
# Total reads processed: 643000000
# Counter({'transcriptomic': 45833748})
# Total reads processed: 644000000
# Counter({'transcriptomic': 45914916})
# Total reads processed: 645000000
# Counter({'transcriptomic': 45994819})
# Total reads processed: 646000000
# Counter({'transcriptomic': 46076578})
# Total reads processed: 647000000
# Counter({'transcriptomic': 46155702})
# Total reads processed: 648000000
# Counter({'transcriptomic': 46224660})
# Total reads processed: 649000000
# Counter({'transcriptomic': 46252901})
# Total reads processed: 650000000
# Counter({'transcriptomic': 46281413})
# Total reads processed: 651000000
# Counter({'transcriptomic': 46309521})
# Total reads processed: 652000000
# Counter({'transcriptomic': 46325019})
# Total reads processed: 653000000
# Counter({'transcriptomic': 46325021})
# Total reads processed: 654000000
# Counter({'transcriptomic': 46335810})
# Total reads processed: 655000000
# Counter({'transcriptomic': 46407192})
# Total reads processed: 656000000
# Counter({'transcriptomic': 46484656})
# Total reads processed: 657000000
# Counter({'transcriptomic': 46562168})
# Total reads processed: 658000000
# Counter({'transcriptomic': 46640450})
# Total reads processed: 659000000
# Counter({'transcriptomic': 46699543})
# Total reads processed: 660000000
# Counter({'transcriptomic': 46770053})
# Total reads processed: 661000000
# Counter({'transcriptomic': 46855388})
# Total reads processed: 662000000
# Counter({'transcriptomic': 46945194})
# Total reads processed: 663000000
# Counter({'transcriptomic': 47040897})
# Total reads processed: 664000000
# Counter({'transcriptomic': 47121780})
# Total reads processed: 665000000
# Counter({'transcriptomic': 47199109})
# Total reads processed: 666000000
# Counter({'transcriptomic': 47287219})
# Total reads processed: 667000000
# Counter({'transcriptomic': 47382905})
# Total reads processed: 668000000
# Counter({'transcriptomic': 47443463})
# Total reads processed: 669000000
# Counter({'transcriptomic': 47528285})
# Total reads processed: 670000000
# Counter({'transcriptomic': 47622206})
# Total reads processed: 671000000
# Counter({'transcriptomic': 47712019})
# Total reads processed: 672000000
# Counter({'transcriptomic': 47786413})
# Total reads processed: 673000000
# Counter({'transcriptomic': 47846026})
# Total reads processed: 674000000
# Counter({'transcriptomic': 47922990})
# Total reads processed: 675000000
# Counter({'transcriptomic': 48016111})
# Total reads processed: 676000000
# Counter({'transcriptomic': 48094137})
# Total reads processed: 677000000
# Counter({'transcriptomic': 48187861})
# Total reads processed: 678000000
# Counter({'transcriptomic': 48275336})
# Total reads processed: 679000000
# Counter({'transcriptomic': 48367499})
# ...
# Total reads processed: 3026000000
# Counter({'transcriptomic': 206415067})
# Total reads processed: 3027000000
# Counter({'transcriptomic': 206514978})
# Total reads processed: 3028000000
# Counter({'transcriptomic': 206604026})
# Total reads processed: 3029000000
# Counter({'transcriptomic': 206689753})
# Total reads processed: 3030000000
# Counter({'transcriptomic': 206768282})
# Total reads processed: 3031000000
# Counter({'transcriptomic': 206839931})
# Total reads processed: 3032000000
# Counter({'transcriptomic': 206918480})
# Total reads processed: 3033000000
# Counter({'transcriptomic': 206974511})
# Total reads processed: 3034000000
# Counter({'transcriptomic': 207057987})
# Total reads processed: 3035000000
# Counter({'transcriptomic': 207117563})
# Total reads processed: 3036000000
# Counter({'transcriptomic': 207117563})
# Total reads processed: 3037000000
# Counter({'transcriptomic': 207117563})
# Total reads processed: 3038000000
# Counter({'transcriptomic': 207168171})
# Total reads processed: 3039000000
# Counter({'transcriptomic': 207251891})
# Total reads processed: 3040000000
# Counter({'transcriptomic': 207329372})
# Total reads processed: 3041000000
# Counter({'transcriptomic': 207419352})
# Total reads processed: 3042000000
# Counter({'transcriptomic': 207518208})
# Total reads processed: 3043000000
# Counter({'transcriptomic': 207603695})
# Total reads processed: 3044000000
# Counter({'transcriptomic': 207679348})
# Total reads processed: 3045000000
# Counter({'transcriptomic': 207762730})
# Total reads processed: 3046000000
# Counter({'transcriptomic': 207849897})
# Total reads processed: 3047000000
# Counter({'transcriptomic': 207944884})
# Total reads processed: 3048000000
# Counter({'transcriptomic': 208040798})
# Total reads processed: 3049000000
# Counter({'transcriptomic': 208131598})
# Total reads processed: 3050000000
# Counter({'transcriptomic': 208224197})
# Total reads processed: 3051000000
# Counter({'transcriptomic': 208311123})
# Total reads processed: 3052000000
# Counter({'transcriptomic': 208401610})
# Total reads processed: 3053000000
# Counter({'transcriptomic': 208493592})
# Total reads processed: 3054000000
# Counter({'transcriptomic': 208588973})
# Total reads processed: 3055000000
# Counter({'transcriptomic': 208682620})
# Total reads processed: 3056000000
# Counter({'transcriptomic': 208758052})
# Total reads processed: 3057000000
# Counter({'transcriptomic': 208849022})
# Total reads processed: 3058000000
# Counter({'transcriptomic': 208941395})
# Total reads processed: 3059000000
# Counter({'transcriptomic': 208997292})
# Total reads processed: 3060000000
# Counter({'transcriptomic': 208997292})
# Total reads processed: 3061000000
# Counter({'transcriptomic': 208997292})
# Total reads processed: 3062000000
# Counter({'transcriptomic': 208997292})
# Total reads processed: 3063000000
# Counter({'transcriptomic': 208997292})
# Total reads processed: 3064000000
# Counter({'transcriptomic': 208997292})
# Total reads processed: 3065000000
# Counter({'transcriptomic': 208997292})
# Total reads processed: 3066000000
# Counter({'transcriptomic': 208997292})
# Total reads processed: 3067000000
# Counter({'transcriptomic': 208997292})
# Total reads processed: 3068000000
# Counter({'transcriptomic': 208997292})
# Total reads processed: 3069000000
# Counter({'transcriptomic': 209043787})
# Total reads processed: 3070000000
# Counter({'transcriptomic': 209127670})
# Total reads processed: 3071000000
# Counter({'transcriptomic': 209209424})
# Total reads processed: 3072000000
# Counter({'transcriptomic': 209288619})
# Total reads processed: 3073000000
# Counter({'transcriptomic': 209315184})
# Total reads processed: 3074000000
# Counter({'transcriptomic': 209372048})
# Total reads processed: 3075000000
# Counter({'transcriptomic': 209454033})
# Total reads processed: 3076000000
# Counter({'transcriptomic': 209553663})
# Total reads processed: 3077000000
# Counter({'transcriptomic': 209647966})
# Total reads processed: 3078000000
# Counter({'transcriptomic': 209746401})
# Total reads processed: 3079000000
# Counter({'transcriptomic': 209838606})
# Total reads processed: 3080000000
# Counter({'transcriptomic': 209928436})
# Total reads processed: 3081000000
# Counter({'transcriptomic': 210026792})
# Total reads processed: 3082000000
# Counter({'transcriptomic': 210107826})
# Total reads processed: 3083000000
# Counter({'transcriptomic': 210207061})
# Total reads processed: 3084000000
# Counter({'transcriptomic': 210306431})
# Total reads processed: 3085000000
# Counter({'transcriptomic': 210397378})
# Total reads processed: 3086000000
# Counter({'transcriptomic': 210486186})
# Total reads processed: 3087000000
# Counter({'transcriptomic': 210574293})
# Total reads processed: 3088000000
# Counter({'transcriptomic': 210602328})
# Total reads processed: 3089000000
# Counter({'transcriptomic': 210698443})
# Total reads processed: 3090000000
# Counter({'transcriptomic': 210771293})
# Total reads processed: 3091000000
# Counter({'transcriptomic': 210859301})
# Total reads processed: 3092000000
# Counter({'transcriptomic': 210941339})
# Total reads processed: 3093000000
# Counter({'transcriptomic': 210975508})
# Total reads processed: 3094000000
# Counter({'transcriptomic': 211023803})
# Total reads processed: 3095000000
# Counter({'transcriptomic': 211098215})
# Total reads processed: 3096000000
# Counter({'transcriptomic': 211167824})
# Total reads processed: 3097000000
# Counter({'transcriptomic': 211222254})
# Total reads processed: 3098000000
# Counter({'transcriptomic': 211258132})
# Total reads processed: 3099000000
# Counter({'transcriptomic': 211258139})
# Total reads processed: 3100000000
# Counter({'transcriptomic': 211258151})
# Total reads processed: 3101000000
# Counter({'transcriptomic': 211258160})
# Total reads processed: 3102000000
# Counter({'transcriptomic': 211258160})
# Total reads processed: 3103000000
# Counter({'transcriptomic': 211258175})
# Total reads processed: 3104000000
# Counter({'transcriptomic': 211258196})
# Total reads processed: 3105000000
# Counter({'transcriptomic': 211258210})
# Total reads processed: 3106000000
# Counter({'transcriptomic': 211258252})
# Total reads processed: 3107000000
# Counter({'transcriptomic': 211258274})
# Total reads processed: 3108000000
# Counter({'transcriptomic': 211258280})
# Total reads processed: 3109000000
# Counter({'transcriptomic': 211258285})
# Total reads processed: 3110000000
# Counter({'transcriptomic': 211258296})
# Total reads processed: 3111000000
# Counter({'transcriptomic': 211258310})
# Total reads processed: 3112000000
# Counter({'transcriptomic': 211258328})
# Total reads processed: 3113000000
# Counter({'transcriptomic': 211258350})
# Total reads processed: 3114000000
# Counter({'transcriptomic': 211258364})
# Total reads processed: 3115000000
# Counter({'transcriptomic': 211258401})
# Total reads processed: 3116000000
# Counter({'transcriptomic': 211258421})
# Total reads processed: 3117000000
# Counter({'transcriptomic': 211258430})
# Total reads processed: 3118000000
# Counter({'transcriptomic': 211258433})
# Total reads processed: 3119000000
# Counter({'transcriptomic': 211258434})
# Total reads processed: 3120000000
# Counter({'transcriptomic': 211258439})
# Total reads processed: 3121000000
# Counter({'transcriptomic': 211258465})
# Total reads processed: 3122000000
# Counter({'transcriptomic': 211288765})
# Total reads processed: 3123000000
# Counter({'transcriptomic': 211376288})
# Total reads processed: 3124000000
# Counter({'transcriptomic': 211473819})
# Total reads processed: 3125000000
# Counter({'transcriptomic': 211571355})
# Total reads processed: 3126000000
# Counter({'transcriptomic': 211666499})
# Total reads processed: 3127000000
# Counter({'transcriptomic': 211763708})
# Total reads processed: 3128000000
# Counter({'transcriptomic': 211798896})
# Total reads processed: 3129000000
# Counter({'transcriptomic': 211867395})
# Total reads processed: 3130000000
# Counter({'transcriptomic': 211921107})
# Total reads processed: 3131000000
# Counter({'transcriptomic': 211938849})
# Total reads processed: 3132000000
# Counter({'transcriptomic': 212007853})
# Total reads processed: 3133000000
# Counter({'transcriptomic': 212060347})
# Total reads processed: 3134000000
# Counter({'transcriptomic': 212079877})
# Total reads processed: 3135000000
# Counter({'transcriptomic': 212164720})
# Total reads processed: 3136000000
# Counter({'transcriptomic': 212262267})
# Total reads processed: 3137000000
# Counter({'transcriptomic': 212360479})
# Total reads processed: 3138000000
# Counter({'transcriptomic': 212459096})
# Total reads processed: 3139000000
# Counter({'transcriptomic': 212522028})
# Total reads processed: 3140000000
# Counter({'transcriptomic': 212561845})
# Total reads processed: 3141000000
# Counter({'transcriptomic': 212568342})
# Total reads processed: 3142000000
# Counter({'transcriptomic': 212619903})
# Total reads processed: 3143000000
# Counter({'transcriptomic': 212713672})
# Total reads processed: 3144000000
# Counter({'transcriptomic': 212810647})
# Total reads processed: 3145000000
# Counter({'transcriptomic': 212910086})
# Total reads processed: 3146000000
# Counter({'transcriptomic': 213008940})
# Total reads processed: 3147000000
# Counter({'transcriptomic': 213041953})
# Total reads processed: 3148000000
# Counter({'transcriptomic': 213041953})
# Total reads processed: 3149000000
# Counter({'transcriptomic': 213041953})
# Total reads processed: 3150000000
# Counter({'transcriptomic': 213041953})
# Total reads processed: 3151000000
# Counter({'transcriptomic': 213052957})
# Total reads processed: 3152000000
# Counter({'transcriptomic': 213132612})
# Total reads processed: 3153000000
# Counter({'transcriptomic': 213216193})
# Total reads processed: 3154000000
# Counter({'transcriptomic': 213309564})
# Total reads processed: 3155000000
# Counter({'transcriptomic': 213407063})
# Total reads processed: 3156000000
# Counter({'transcriptomic': 213469228})
# Total reads processed: 3157000000
# Counter({'transcriptomic': 213556044})
# Total reads processed: 3158000000
# Counter({'transcriptomic': 213639093})
# Total reads processed: 3159000000
# Counter({'transcriptomic': 213726699})
# Total reads processed: 3160000000
# Counter({'transcriptomic': 213750528})
# Total reads processed: 3161000000
# Counter({'transcriptomic': 213817697})
# Total reads processed: 3162000000
# Counter({'transcriptomic': 213910161})
# Total reads processed: 3163000000
# Counter({'transcriptomic': 214004304})
# Total reads processed: 3164000000
# Counter({'transcriptomic': 214086738})
# Total reads processed: 3165000000
# Counter({'transcriptomic': 214157030})
# Total reads processed: 3166000000
# Counter({'transcriptomic': 214249574})
# Total reads processed: 3167000000
# Counter({'transcriptomic': 214328102})
# Total reads processed: 3168000000
# Counter({'transcriptomic': 214390152})
# Total reads processed: 3169000000
# Counter({'transcriptomic': 214477102})
# Total reads processed: 3170000000
# Counter({'transcriptomic': 214549426})
# Total reads processed: 3171000000
# Counter({'transcriptomic': 214621566})
# Total reads processed: 3172000000
# Counter({'transcriptomic': 214695639})
# Total reads processed: 3173000000
# Counter({'transcriptomic': 214741309})
# Total reads processed: 3174000000
# Counter({'transcriptomic': 214741326})
# Total reads processed: 3175000000
# Counter({'transcriptomic': 214817769})
# Total reads processed: 3176000000
# Counter({'transcriptomic': 214902746})
# Total reads processed: 3177000000
# Counter({'transcriptomic': 214942887})
# Total reads processed: 3178000000
# Counter({'transcriptomic': 215031980})
# Total reads processed: 3179000000
# Counter({'transcriptomic': 215106054})
# Total reads processed: 3180000000
# Counter({'transcriptomic': 215199659})
# Total reads processed: 3181000000
# Counter({'transcriptomic': 215287865})
# Total reads processed: 3182000000
# Counter({'transcriptomic': 215371296})
# Total reads processed: 3183000000
# Counter({'transcriptomic': 215462323})
# Total reads processed: 3184000000
# Counter({'transcriptomic': 215548369})
# Total reads processed: 3185000000
# Counter({'transcriptomic': 215609785})
# Total reads processed: 3186000000
# Counter({'transcriptomic': 215675051})
# Total reads processed: 3187000000
# Counter({'transcriptomic': 215755525})
# Total reads processed: 3188000000
# Counter({'transcriptomic': 215853782})
# Total reads processed: 3189000000
# Counter({'transcriptomic': 215927037})
# Total reads processed: 3190000000
# Counter({'transcriptomic': 216008400})
# Total reads processed: 3191000000
# Counter({'transcriptomic': 216045544})
# Total reads processed: 3192000000
# Counter({'transcriptomic': 216106930})
# Total reads processed: 3193000000
# Counter({'transcriptomic': 216173969})
# Total reads processed: 3194000000
# Counter({'transcriptomic': 216246226})
# Total reads processed: 3195000000
# Counter({'transcriptomic': 216317585})
# Total reads processed: 3196000000
# Counter({'transcriptomic': 216402283})
# Total reads processed: 3197000000
# Counter({'transcriptomic': 216494154})
# Total reads processed: 3198000000
# Counter({'transcriptomic': 216564546})
# Total reads processed: 3199000000
# Counter({'transcriptomic': 216630220})
# Total reads processed: 3200000000
# Counter({'transcriptomic': 216722383})
# Total reads processed: 3201000000
# Counter({'transcriptomic': 216781559})
# Total reads processed: 3202000000
# Counter({'transcriptomic': 216850478})
# Total reads processed: 3203000000
# Counter({'transcriptomic': 216946087})
# Total reads processed: 3204000000
# Counter({'transcriptomic': 217044042})
# Total reads processed: 3205000000
# Counter({'transcriptomic': 217143721})
# Total reads processed: 3206000000
# Counter({'transcriptomic': 217241990})
# Total reads processed: 3207000000
# Counter({'transcriptomic': 217328234})
# Total reads processed: 3208000000
# Counter({'transcriptomic': 217423479})
# Total reads processed: 3209000000
# Counter({'transcriptomic': 217509697})
# Total reads processed: 3210000000
# Counter({'transcriptomic': 217607590})
# Total reads processed: 3211000000
# Counter({'transcriptomic': 217703608})
# Total reads processed: 3212000000
# Counter({'transcriptomic': 217782944})
# Total reads processed: 3213000000
# Counter({'transcriptomic': 217879885})
# Total reads processed: 3214000000
# Counter({'transcriptomic': 217979363})
# Total reads processed: 3215000000
# Counter({'transcriptomic': 218078363})
# Total reads processed: 3216000000
# Counter({'transcriptomic': 218178104})
# Total reads processed: 3217000000
# Counter({'transcriptomic': 218277685})
# Total reads processed: 3218000000
# Counter({'transcriptomic': 218372537})
# Total reads processed: 3219000000
# Counter({'transcriptomic': 218465244})
# Total reads processed: 3220000000
# Counter({'transcriptomic': 218536927})
# Total reads processed: 3221000000
# Counter({'transcriptomic': 218611648})
# Total reads processed: 3222000000
# Counter({'transcriptomic': 218685769})
# Total reads processed: 3223000000
# Counter({'transcriptomic': 218757695})
# Total reads processed: 3224000000
# Counter({'transcriptomic': 218832889})
# Total reads processed: 3225000000
# Counter({'transcriptomic': 218907993})
# Total reads processed: 3226000000
# Counter({'transcriptomic': 218994643})
# Total reads processed: 3227000000
# Counter({'transcriptomic': 219075190})
# Total reads processed: 3228000000
# Counter({'transcriptomic': 219148750})
# Total reads processed: 3229000000
# Counter({'transcriptomic': 219232516})
# Total reads processed: 3230000000
# Counter({'transcriptomic': 219320641})
# Total reads processed: 3231000000
# Counter({'transcriptomic': 219417764})
# Total reads processed: 3232000000
# Counter({'transcriptomic': 219515096})
# Total reads processed: 3233000000
# Counter({'transcriptomic': 219614541})
# Total reads processed: 3234000000
# Counter({'transcriptomic': 219714716})
# Total reads processed: 3235000000
# Counter({'transcriptomic': 219814771})
# Total reads processed: 3236000000
# Counter({'transcriptomic': 219914872})
# Total reads processed: 3237000000
# Counter({'transcriptomic': 220014050})
# Total reads processed: 3238000000
# Counter({'transcriptomic': 220114429})
# Total reads processed: 3239000000
# Counter({'transcriptomic': 220214572})
# Total reads processed: 3240000000
# Counter({'transcriptomic': 220313532})
# Total reads processed: 3241000000
# Counter({'transcriptomic': 220412620})
# Total reads processed: 3242000000
# Counter({'transcriptomic': 220506083})
# Total reads processed: 3243000000
# Counter({'transcriptomic': 220549095})
# Total reads processed: 3244000000
# Counter({'transcriptomic': 220582151})

# %%
from scipy.io import mmwrite

# %%
for prop in sub_props1:
    out_dir = f"./total_downsampled/{prop}"
    if not os.path.exists(out_dir):
        os.makedirs(out_dir)
    write_mtx(gene_count_dict[prop],out_dir)
# Out:
# ['21102_8039', '10017_8562', '7175_19258', '12773_12980', '15364_5138', '10399_20673', '17339_8464', '18751_9227', '12123_13006', '12059_16818']
# ['Xkr4', 'Gm1992', 'Gm37381', 'Rp1', 'Mrpl15', 'Sox17', 'Lypla1', 'Rgs20', 'Gm37988', 'Tcea1']
